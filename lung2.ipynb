# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

# %%
from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
pip install Pillow
# Out:
# Collecting Pillow
#   Downloading Pillow-9.3.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.8 MB/s eta 0:00:00
# Installing collected packages: Pillow
# Successfully installed Pillow-9.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

# %%
from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.2-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91797\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91797\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp310-cp310-win_amd64.whl (163 kB)
#      -------------------------------------- 163.6/163.6 kB 3.3 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      -------------------------------------- 965.4/965.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\91797\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\91797\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (9.3.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in c:\users\91797\anaconda3\envs\tensorflow\lib\site-packages (from matplotlib) (1.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\91797\anaconda3\envs\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.6 cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.4 matplotlib-3.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

# %%
from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 472ms/step
# The X-RAY indicates the presence of CANCER

# %%
img = image.load_img('Val/NORMAL/NORMAL2-IM-1430-0001.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 128ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5804\1148466558.py in <module>
#      10 from matplotlib.pyplot import imshow
#      11
# ---> 12 img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
#      13 img = image.img_to_array(img)
#      14 img = img/255
#
# AttributeError: module 'keras.preprocessing.image' has no attribute 'load_img'

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 12
#       9 import matplotlib.pyplot as plt
#      10 from matplotlib.pyplot import imshow
# ---> 12 img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
#      13 img = image.img_to_array(img)
#      14 img = img/255
#
# AttributeError: module 'keras.preprocessing.image' has no attribute 'load_img'

# %%
from tensorflow.keras.utils import load_img, img_to_array

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 12
#       9 import matplotlib.pyplot as plt
#      10 from matplotlib.pyplot import imshow
# ---> 12 img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
#      13 img = image.img_to_array(img)
#      14 img = img/255
#
# AttributeError: module 'keras.preprocessing.image' has no attribute 'load_img'

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

# %%
from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 255ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5804\1148466558.py in <module>
#      10 from matplotlib.pyplot import imshow
#      11
# ---> 12 img = image.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
#      13 img = image.img_to_array(img)
#      14 img = img/255
#
# AttributeError: module 'keras.preprocessing.image' has no attribute 'load_img'

# %%
import keras

# %%
import tensorflow

# %%
keras.utils.load_img
# Out:
# <function keras.utils.image_utils.load_img(path, grayscale=False, color_mode='rgb', target_size=None, interpolation='nearest', keep_aspect_ratio=False)>

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5804\3343394006.py in <module>
#      11
#      12 img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
# ---> 13 img = image.img_to_array(img)
#      14 img = img/255
#      15 imshow(img)
#
# AttributeError: module 'keras.preprocessing.image' has no attribute 'img_to_array'

# %%
from tensorflow.keras.utils import load_img, img_to_array

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = image.img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5804\3343394006.py in <module>
#      11
#      12 img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
# ---> 13 img = image.img_to_array(img)
#      14 img = img/255
#      15 imshow(img)
#
# AttributeError: module 'keras.preprocessing.image' has no attribute 'img_to_array'

# %%
from tensorflow.keras.utils import load_img, img_to_array

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 323ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1430-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 260ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1437-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002421F640EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 256ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1437-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1340\295033027.py in <module>
#      10 from matplotlib.pyplot import imshow
#      11
# ---> 12 img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1437-0001.jpeg', target_size=(224, 224))
#      13 img = img_to_array(img)
#      14 img = img/255
#
# NameError: name 'keras' is not defined

# %%
import keras

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1437-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1340\295033027.py in <module>
#      11
#      12 img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1437-0001.jpeg', target_size=(224, 224))
# ---> 13 img = img_to_array(img)
#      14 img = img/255
#      15 imshow(img)
#
# NameError: name 'img_to_array' is not defined

# %%
from tensorflow.keras.utils import load_img, img_to_array

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1437-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 1s 710ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1427-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 471ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1431-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 1s 508ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1436-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 470ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1440-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000016F08F3F820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 460ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1438-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000016F09A800D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 472ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/NORMAL/NORMAL2-IM-1442-0001.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 494ms/step
# The X-Ray is NORMAL

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4874.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 455ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1946_bacteria_4875.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 471ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1947_bacteria_4876.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 456ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1949_bacteria_4880.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 459ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1950_bacteria_4881.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 465ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1951_bacteria_4882.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 441ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1952_bacteria_4883.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 474ms/step
# The X-RAY indicates the presence of CANCER

# %%
from tensorflow.keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import numpy as np

from tensorflow.keras.models import load_model
lo_model=load_model('lu_prediction.h5')
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

img = keras.utils.load_img('Val/CANCEROUS/person1954_bacteria_4886.jpeg', target_size=(224, 224))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = lo_model.predict(img)

if answer[0][0] > 0.5:
    print("The X-Ray is NORMAL")
else:
    print("The X-RAY indicates the presence of CANCER")
# Out:
# 1/1 [==============================] - 0s 466ms/step
# The X-RAY indicates the presence of CANCER
